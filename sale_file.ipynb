# %%
import json

fd = open("records.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
record
# Out:
# {'1000': {'name': 'cake',
#   'price': 100,
#   'qty': 200,
#   'taste': 'sweet',
#   'weight': 70},
#  '1001': {'name': 'drink',
#   'price': 60,
#   'qty': 250,
#   'taste': 'sweet',
#   'weight': 120},
#  '1002': {'name': 'candy',
#   'price': 5,
#   'qty': 300,
#   'taste': 'sweet',
#   'weight': 5},
#  '1003': {'name': 'pen',
#   'price': 1200,
#   'qty': 270,
#   'taste': 'none',
#   'weight': 370},
#  '1004': {'name': 'mike',
#   'price': 1400,
#   'qty': 280,
#   'taste': 'none',
#   'weight': 470},
#  '1005': {'name': 'chocolate cake',
#   'price': 170,
#   'qty': 230,
#   'taste': 'sweet',
#   'weight': 70},
#  '1006': {'name': 'oil',
#   'price': 120,
#   'qty': 1000,
#   'taste': 'none',
#   'weight': 500},
#  '1007': {'name': 'biscuit',
#   'price': 21,
#   'qty': 45,
#   'taste': 'sweet',
#   'weight': 50},
#  '1008': {'name': 'bisleri',
#   'price': 20,
#   'qty': 123,
#   'taste': 'none',
#   'weight': 670},
#  '1009': {'name': 'pizza base',
#   'price': 30,
#   'qty': 500,
#   'taste': 'none',
#   'weight': 25},
#  '1010': {'name': 'chilly sauce',
#   'price': 76,
#   'qty': 45,
#   'taste': 'spicy',
#   'weight': 400},
#  '1011': {'name': 'almonds',
#   'price': 450,
#   'qty': 120,
#   'taste': 'sweet',
#   'weight': 500},
#  '1012': {'name': 'wheat flour',
#   'price': 250,
#   'qty': 400,
#   'taste': 'none',
#   'weight': 5000},
#  '1013': {'name': 'pickles',
#   'price': 65,
#   'qty': 98,
#   'taste': 'spicy',
#   'weight': 250},
#  '1014': {'name': 'black pepper',
#   'price': 300,
#   'qty': 120,
#   'taste': 'spicy',
#   'weight': 900},
#  '1015': {'name': 'cinnamon stick',
#   'price': 300,
#   'qty': 65,
#   'taste': 'spicy',
#   'weight': 250},
#  '1016': {'name': 'rajma',
#   'price': 90,
#   'qty': 100,
#   'taste': 'none',
#   'weight': 100},
#  '1017': {'name': 'maggi masala',
#   'price': 25,
#   'qty': 78,
#   'taste': 'spicy',
#   'weight': 50},
#  '1018': {'name': 'milk powder',
#   'price': 250,
#   'qty': 120,
#   'taste': 'sweet',
#   'weight': 500},
#  '1019': {'name': 'mushroom',
#   'price': 90,
#   'qty': 78,
#   'taste': 'none',
#   'weight': 250},
#  '1020': {'name': 'olive',
#   'price': 250,
#   'qty': 50,
#   'taste': 'none',
#   'weight': 250},
#  '1021': {'name': 'corn',
#   'price': 100,
#   'qty': 55,
#   'taste': 'sweet',
#   'weight': 1000},
#  '1022': {'name': 'amla powder',
#   'price': 99,
#   'qty': 60,
#   'taste': 'none',
#   'weight': 1000},
#  '1023': {'name': 'chhole',
#   'price': 90,
#   'qty': 100,
#   'taste': 'none',
#   'weight': 970},
#  '1024': {'name': 'mts rava idli mix',
#   'price': 55,
#   'qty': 50,
#   'taste': 'salty',
#   'weight': 450},
#  '1025': {'name': 'gram flour',
#   'price': 85,
#   'qty': 20,
#   'taste': 'none',
#   'weight': 950},
#  '1026': {'name': 'rava',
#   'price': 45,
#   'qty': 120,
#   'taste': 'none',
#   'weight': 1000},
#  '1027': {'name': 'mc cans',
#   'price': 50,
#   'qty': 50,
#   'taste': 'salty',
#   'weight': 450},
#  '1028': {'name': 'coffe',
#   'price': 125,
#   'qty': 45,
#   'taste': 'none',
#   'weight': 450},
#  '1029': {'name': 'turmeric powder',
#   'price': 150,
#   'qty': 100,
#   'taste': 'spicy',
#   'weight': 980},
#  '1030': {'name': 'tropicano',
#   'price': 155,
#   'qty': 85,
#   'taste': 'sweet',
#   'weight': 750},
#  '1031': {'name': 'vanilla essence',
#   'price': 50,
#   'qty': 40,
#   'taste': 'sweet',
#   'weight': 55},
#  '1032': {'name': 'vanilla custard powder',
#   'price': 60,
#   'qty': 80,
#   'taste': 'sweet',
#   'weight': 200},
#  '1033': {'name': 'tea tree oil',
#   'price': 250,
#   'qty': 40,
#   'taste': 'none',
#   'weight': 100},
#  '1034': {'name': 'banana chips',
#   'price': 120,
#   'qty': 50,
#   'taste': 'salty',
#   'weight': 450},
#  '1035': {'name': 'lays',
#   'price': 50,
#   'qty': 250,
#   'taste': 'salty',
#   'weight': 100},
#  '1036': {'name': 'sabudana',
#   'price': 95,
#   'qty': 40,
#   'taste': 'none',
#   'weight': 700},
#  '1037': {'name': 'apple cider vinegar',
#   'price': 850,
#   'qty': 55,
#   'taste': 'sour',
#   'weight': 950},
#  '1038': {'name': 'sugar lite',
#   'price': 200,
#   'qty': 50,
#   'taste': 'sweet',
#   'weight': 150},
#  '1039': {'name': 'mozorilla cheese',
#   'price': 99,
#   'qty': 80,
#   'taste': 'sweet ',
#   'weight': 200},
#  '1040': {'name': 'oats',
#   'price': 95,
#   'qty': 350,
#   'taste': 'none',
#   'weight': 850}}

# %%
fd = open("sales.json",'r')
r = fd.read()
fd.close()

sale = json.loads(r)
sale
# Out:
# {'1': {'prod': '1004', 'qty': 1, 'amount': 1400},
#  '2': {'prod': '1000', 'qty': 1, 'amount': 100},
#  '3': {'prod': '1002', 'qty': 1, 'amount': 5},
#  '4': {'prod': '1003', 'qty': 1, 'amount': 1200},
#  '5': {'prod': '1005', 'qty': 2, 'amount': 340},
#  '6': {'prod': '1006', 'qty': 3, 'amount': 360},
#  '7': {'prod': '1008', 'qty': 4, 'amount': 80},
#  '8': {'prod': '1010', 'qty': 3, 'amount': 228},
#  '9': {'prod': '1027', 'qty': 1, 'amount': 50},
#  '10': {'prod': '1024', 'qty': 1, 'amount': 55},
#  '11': {'prod': '1025', 'qty': 1, 'amount': 85},
#  '12': {'prod': '1038', 'qty': 7, 'amount': 1400},
#  '13': {'prod': '1009', 'qty': 2, 'amount': 60},
#  '14': {'prod': '1022', 'qty': 1, 'amount': 99}}

# %%
#purchase a item
ui_prod  = str(input("Enter the product_Id: "))
ui_quant = int(input("Enter the quantity: "))


print("Product: ", record[ui_prod]['name'])
print("Price: ", record[ui_prod]['price'])
print("----------------------------------------")
print("Billing Amount: ", record[ui_prod]['price'] * ui_quant)
print("----------------------------------------")

record[ui_prod]['qty'] = record[ui_prod]['qty'] - ui_quant
js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter the product_Id: 1009
# Enter the quantity: 1
# Product:  pizza base
# Price:  30
# ----------------------------------------
# Billing Amount:  30
# ----------------------------------------

# %%
record
# Out:
# {'1000': {'name': 'cake',
#   'price': 100,
#   'qty': 199,
#   'taste': 'sweet',
#   'weight': 70},
#  '1001': {'name': 'drink',
#   'price': 60,
#   'qty': 249,
#   'taste': 'sweet',
#   'weight': 120},
#  '1002': {'name': 'candy',
#   'price': 5,
#   'qty': 299,
#   'taste': 'sweet',
#   'weight': 5},
#  '1003': {'name': 'pen',
#   'price': 1200,
#   'qty': 269,
#   'taste': 'none',
#   'weight': 370},
#  '1004': {'name': 'mike',
#   'price': 1400,
#   'qty': 279,
#   'taste': 'none',
#   'weight': 470},
#  '1005': {'name': 'chocolate cake',
#   'price': 170,
#   'qty': 230,
#   'taste': 'sweet',
#   'weight': 70},
#  '1006': {'name': 'oil',
#   'price': 120,
#   'qty': 1000,
#   'taste': 'none',
#   'weight': 500},
#  '1007': {'name': 'biscuit',
#   'price': 21,
#   'qty': 44,
#   'taste': 'sweet',
#   'weight': 50},
#  '1008': {'name': 'bisleri',
#   'price': 20,
#   'qty': 120,
#   'taste': 'none',
#   'weight': 670},
#  '1009': {'name': 'pizza base',
#   'price': 30,
#   'qty': 499,
#   'taste': 'none',
#   'weight': 25},
#  '1010': {'name': 'chilly sauce',
#   'price': 76,
#   'qty': 45,
#   'taste': 'spicy',
#   'weight': 400},
#  '1011': {'name': 'almonds',
#   'price': 450,
#   'qty': 120,
#   'taste': 'sweet',
#   'weight': 500},
#  '1012': {'name': 'wheat flour',
#   'price': 250,
#   'qty': 400,
#   'taste': 'none',
#   'weight': 5000},
#  '1013': {'name': 'pickles',
#   'price': 65,
#   'qty': 98,
#   'taste': 'spicy',
#   'weight': 250},
#  '1014': {'name': 'black pepper',
#   'price': 300,
#   'qty': 120,
#   'taste': 'spicy',
#   'weight': 900},
#  '1015': {'name': 'cinnamon stick',
#   'price': 300,
#   'qty': 65,
#   'taste': 'spicy',
#   'weight': 250},
#  '1016': {'name': 'rajma',
#   'price': 90,
#   'qty': 100,
#   'taste': 'none',
#   'weight': 100},
#  '1017': {'name': 'maggi masala',
#   'price': 25,
#   'qty': 78,
#   'taste': 'spicy',
#   'weight': 50},
#  '1018': {'name': 'milk powder',
#   'price': 250,
#   'qty': 120,
#   'taste': 'sweet',
#   'weight': 500},
#  '1019': {'name': 'mushroom',
#   'price': 90,
#   'qty': 78,
#   'taste': 'none',
#   'weight': 250},
#  '1020': {'name': 'olive',
#   'price': 250,
#   'qty': 49,
#   'taste': 'none',
#   'weight': 250},
#  '1021': {'name': 'corn',
#   'price': 100,
#   'qty': 54,
#   'taste': 'sweet',
#   'weight': 1000},
#  '1022': {'name': 'amla powder',
#   'price': 99,
#   'qty': 60,
#   'taste': 'none',
#   'weight': 1000},
#  '1023': {'name': 'chhole',
#   'price': 90,
#   'qty': 99,
#   'taste': 'none',
#   'weight': 970},
#  '1024': {'name': 'mts rava idli mix',
#   'price': 55,
#   'qty': 50,
#   'taste': 'salty',
#   'weight': 450},
#  '1025': {'name': 'gram flour',
#   'price': 85,
#   'qty': 20,
#   'taste': 'none',
#   'weight': 950},
#  '1026': {'name': 'rava',
#   'price': 45,
#   'qty': 119,
#   'taste': 'none',
#   'weight': 1000},
#  '1027': {'name': 'mc cans',
#   'price': 50,
#   'qty': 49,
#   'taste': 'salty',
#   'weight': 450},
#  '1028': {'name': 'coffe',
#   'price': 125,
#   'qty': 44,
#   'taste': 'none',
#   'weight': 450},
#  '1029': {'name': 'turmeric powder',
#   'price': 150,
#   'qty': 99,
#   'taste': 'spicy',
#   'weight': 980},
#  '1030': {'name': 'tropicano',
#   'price': 155,
#   'qty': 85,
#   'taste': 'sweet',
#   'weight': 750},
#  '1031': {'name': 'vanilla essence',
#   'price': 50,
#   'qty': 39,
#   'taste': 'sweet',
#   'weight': 55},
#  '1032': {'name': 'vanilla custard powder',
#   'price': 60,
#   'qty': 79,
#   'taste': 'sweet',
#   'weight': 200},
#  '1033': {'name': 'tea tree oil',
#   'price': 250,
#   'qty': 40,
#   'taste': 'none',
#   'weight': 100},
#  '1034': {'name': 'banana chips',
#   'price': 120,
#   'qty': 49,
#   'taste': 'salty',
#   'weight': 450},
#  '1035': {'name': 'lays',
#   'price': 50,
#   'qty': 250,
#   'taste': 'salty',
#   'weight': 100},
#  '1036': {'name': 'sabudana',
#   'price': 95,
#   'qty': 40,
#   'taste': 'none',
#   'weight': 700},
#  '1037': {'name': 'apple cider vinegar',
#   'price': 850,
#   'qty': 55,
#   'taste': 'sour',
#   'weight': 950},
#  '1038': {'name': 'sugar lite',
#   'price': 200,
#   'qty': 50,
#   'taste': 'sweet',
#   'weight': 150},
#  '1039': {'name': 'mozorilla cheese',
#   'price': 99,
#   'qty': 80,
#   'taste': 'sweet ',
#   'weight': 200},
#  '1040': {'name': 'oats',
#   'price': 95,
#   'qty': 350,
#   'taste': 'none',
#   'weight': 850}}

# %%
#sales.json
serial_no = input("enter serial no ")
sale[serial_no]={'prod' : ui_prod, 'qty' : ui_quant, 'amount': record[ui_prod]['price'] * ui_quant}
js = json.dumps(sale)

fd = open("sales.json",'w')


fd.write(js)
fd.close()

sale
# Out:
# enter serial no 33
# {'1': {'prod': '1004', 'qty': 1, 'amount': 1400},
#  '2': {'prod': '1000', 'qty': 1, 'amount': 100},
#  '3': {'prod': '1002', 'qty': 1, 'amount': 5},
#  '4': {'prod': '1003', 'qty': 1, 'amount': 1200},
#  '5': {'prod': '1005', 'qty': 2, 'amount': 340},
#  '6': {'prod': '1006', 'qty': 3, 'amount': 360},
#  '7': {'prod': '1008', 'qty': 4, 'amount': 80},
#  '8': {'prod': '1010', 'qty': 3, 'amount': 228},
#  '9': {'prod': '1027', 'qty': 1, 'amount': 50},
#  '10': {'prod': '1024', 'qty': 1, 'amount': 55},
#  '11': {'prod': '1025', 'qty': 1, 'amount': 85},
#  '12': {'prod': '1038', 'qty': 7, 'amount': 1400},
#  '13': {'prod': '1009', 'qty': 2, 'amount': 60},
#  '14': {'prod': '1022', 'qty': 1, 'amount': 99},
#  '15': {'prod': '1028', 'qty': 1, 'amount': 125},
#  '16': {'prod': '1029', 'qty': 1, 'amount': 150},
#  '17': {'prod': '1031', 'qty': 1, 'amount': 50},
#  '18': {'prod': '1032', 'qty': 1, 'amount': 60},
#  '19': {'prod': '1034', 'qty': 1, 'amount': 120},
#  '21': {'prod': '1020', 'qty': 1, 'amount': 250},
#  '20': {'prod': '1021', 'qty': 1, 'amount': 100},
#  '22': {'prod': '1023', 'qty': 1, 'amount': 90},
#  '23': {'prod': '1026', 'qty': 1, 'amount': 45},
#  '24': {'prod': '1027', 'qty': 1, 'amount': 50},
#  '26': {'prod': '1000', 'qty': 1, 'amount': 100},
#  '25': {'prod': '1001', 'qty': 1, 'amount': 60},
#  '27': {'prod': '1002', 'qty': 1, 'amount': 5},
#  '28': {'prod': '1003', 'qty': 1, 'amount': 1200},
#  '29': {'prod': '1004', 'qty': 1, 'amount': 1400},
#  '30': {'prod': '1007', 'qty': 1, 'amount': 21},
#  '31': {'prod': '1008', 'qty': 2, 'amount': 40},
#  '32': {'prod': '1008', 'qty': 1, 'amount': 20},
#  '33': {'prod': '1009', 'qty': 1, 'amount': 30}}
